# %%
import openai
from openai import OpenAI

# %%
import os

# %%
client = OpenAI()

# %%
response= client.chat.completions.create(
    model="gpt-4o", 
    messages=[{"role":"user", "content":"do know if course began?"}]
)

# %%
response.choices[0].message.content
